# %%
import pandas
from pandas import read_csv

# %%
moving = read_csv('./data/2012-11-12_09:19:34_+0000_Accel.csv',names=['time','q','x','y','z','label'], skiprows=1)

# %%
timestamp = 1352711978.227
start = timestamp -1 
idx = ( moving["time"] > start) & (moving['time'] < timestamp)

# %%
idx.plot()

# %%
moving[idx][['x','y','z']].plot()
